# %%
import pandas as pd

fake = pd.read_csv("../data/raw/Fake.csv")
true = pd.read_csv("../data/raw/True.csv")

fake2 = pd.read_csv("../data/raw/Fake1.csv")
true2 = pd.read_csv("../data/raw/True2.csv")

fake["label"] = 0
true["label"] = 1

data = pd.concat([fake, true]).reset_index(drop=True)

data = data[["title","text","label"]]

data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                          title_clean  \
# 0  donald trump sends embarrassing new year’s eve...
# 1  drunk bragging trump staffer started russian c...
# 2  sheriff david clarke becomes internet joke thr...
# 3  trump obsessed even obama’s name coded website...
# 4  pope francis called donald trump christmas speech
#
#                                                 text  \
# 0  Donald Trump just couldn t wish all Americans ...
# 1  House Intelligence Committee Chairman Devin Nu...
# 2  On Friday, it was revealed that former Milwauk...
# 3  On Christmas day, Donald Trump announced that ...
# 4  Pope Francis used his annual Christmas Day mes...
#
#                                           text_clean  \
# 0  donald trump wish americans happy new year lea...
# 1  house intelligence committee chairman devin nu...
# 2  friday revealed former milwaukee sheriff david...
# 3  christmas day donald trump announced would bac...
# 4  pope francis used annual christmas day message...
#
#                                        combined_text subject        date  \
# 0  donald trump sends embarrassing new year’s eve...    news  2017-12-31
# 1  drunk bragging trump staffer started russian c...    news  2017-12-31
# 2  sheriff david clarke becomes internet joke thr...    news  2017-12-30
# 3  trump obsessed even obama’s name coded website...    news  2017-12-29
# 4  pope francis called donald trump christmas spe...    news  2017-12-25
#
#    word_count  label
# 0         258      0
# 1         178      0
# 2         319      0
# 3         247      0
# 4         211      0

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37903 entries, 0 to 37902
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          37903 non-null  str
#  1   title_clean    37903 non-null  str
#  2   text           37903 non-null  str
#  3   text_clean     37903 non-null  str
#  4   combined_text  37903 non-null  str
#  5   subject        37903 non-null  str
#  6   date           10544 non-null  str
#  7   word_count     37903 non-null  int64
#  8   label          37903 non-null  int64
# dtypes: int64(2), str(7)
# memory usage: 2.6 MB
